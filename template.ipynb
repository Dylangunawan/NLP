# %% [markdown]
# # TF-IDF

# %% [markdown]
# ### Import library

# %%
import nltk

# %% [markdown]
# ### Text declaration - Preprocessing

# %%
first_sentence = "It is going to rain today"
second_sentence = "Today I am not going outside"
# Out:
# {'outside', 'today', 'rain', 'going'}

# %% [markdown]
# ### Creating Word Dictionary

# %%
# Out:
#    outside  today  rain  going
# 0        0      1     1      1
# 1        1      1     0      1

# %% [markdown]
# ### Count TF (Term Frequency)

# %%
# Out:
#     outside     today      rain     going
# 0  0.000000  0.333333  0.333333  0.333333
# 1  0.333333  0.333333  0.000000  0.333333

# %% [markdown]
# ### Count IDF (Inverse Document Frequency)

# %%
# Out:
#      Words      IDF
# 0  outside  0.30103
# 1    today  0.30103
# 2     rain  0.30103
# 3    going  0.30103

# %% [markdown]
# ### Computing TF-IDF

# %%
# Out:
#     outside     today      rain     going
# 0  0.000000  0.100343  0.100343  0.100343
# 1  0.100343  0.100343  0.000000  0.100343

# %% [markdown]
# # Cosine Simliarity

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Import Library

# %% [markdown]
# ### Text Definition - Preprocessing

# %%
document1 = 'It is going to rain today'
document2 = 'Today I am not going outside'
# Out:
# ['It is going to rain today', 'Today I am not going outside']

# %% [markdown]
# ### TF IDF using library instead of manual

# %%
# Out:
# ['going' 'outside' 'rain' 'today']
#
#  Document 1: ['going', 'rain', 'today']
#
#  Document 2: ['today', 'going', 'outside']
#
# X1 : [0.50154891 0.         0.70490949 0.50154891]
#
# X2 : [0.50154891 0.70490949 0.         0.50154891]
#
# Cosine similarity 0.5031026124151314
